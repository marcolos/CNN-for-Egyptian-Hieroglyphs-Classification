# %%
# %run util_img.ipynb
import os
import shutil
import cv2
import numpy as np
import statistics
from scipy import stats
import time
import matplotlib.pyplot as plt

# %% [markdown]
# # Test

# %%
lista = [1,2,3,4,5,6,7,8,9]
lista[len(lista)-5:len(lista)]

# %%
# CHECK VECCHIA VERSIONE CON adjust_white_contorned_img E resize_img

file = "/Users/marco/Desktop/tesi/CampioniL/Aiyn - disegno/0029_D36.jpg"


img_gray = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
plot1 = plt.figure(1)
plt.imshow(img_gray, cmap="gray")
plt.colorbar()


img_gray = adjust_white_contorned_img(img_gray)
plot2 = plt.figure(2)
plt.imshow(img_gray, cmap="gray")
plt.colorbar()


img_gray = resize_img(img_gray, 50, 75, NEAR_PIXEL = 5)
plot3 = plt.figure(3)
plt.imshow(img_gray, cmap="gray")
plt.colorbar()


plt.show()

# %%
# CHECK SCONTORNO DAL BIANCO 

file = "/Users/marco/Desktop/tesi/CampioniL/Aiyn - disegno/0029_D36.jpg"

img = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
plot1 = plt.figure(1)
plt.imshow(img, cmap="gray")
plt.colorbar()

thresh1 = cv2.threshold(img,250,255,cv2.THRESH_BINARY_INV)[1]/255
print(thresh1)

print(img.shape)
print(thresh1.shape)
plot2 = plt.figure(2)
plt.imshow(thresh1, cmap="gray")
plt.colorbar()

# %%
# CHECK SCONTORNO DAL BIANCO CON TUTTO IL DATASET

# dataset path
path = '/Users/marco/Desktop/tesi/CampioniL'
filelist = create_filelist(path) 

for i,file in enumerate(filelist):
    img = cv2.imread(file, cv2.IMREAD_GRAYSCALE)

    ret,thresh1 = cv2.threshold(img,250,255,cv2.THRESH_BINARY)

    plt.figure(i)
    plt.subplot(1,2,1)
    plt.imshow(img, cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(thresh1, cmap='gray')

plt.show()

# %%
# CHECK RESIZE 

fileA = "/Users/marco/Desktop/tesi/CampioniL/Aiyn - disegno/0029_D36.jpg"
fileB = "/Users/marco/Desktop/prova/CampioniL/di - incisione/0004_X8.jpg"

img_grayA = cv2.imread(fileA, cv2.IMREAD_GRAYSCALE)
#img_grayA2 = adjust_white_contorned_img(img_grayA)
#img_grayA2 = resize_img(img_grayA2, 50, 75, NEAR_PIXEL=5)
img_grayA2 = refact_img(img_grayA, 50, 75, NEAR_PIXEL = 5)

img_grayB = cv2.imread(fileB, cv2.IMREAD_GRAYSCALE)
#img_grayB2 = adjust_white_contorned_img(img_grayB)
#img_grayB2 = resize_img(img_grayB2, 50, 75, NEAR_PIXEL=5)
img_grayB2 = refact_img(img_grayB, 50, 75, NEAR_PIXEL = 5)



plot1 = plt.figure(1)
plt.imshow(img_grayA, cmap="gray")
plt.colorbar()


plot2 = plt.figure(2)
plt.imshow(img_grayA2, cmap="gray")
plt.colorbar()

plot1 = plt.figure(3)
plt.imshow(img_grayB, cmap="gray")
plt.colorbar()


plot2 = plt.figure(4)
plt.imshow(img_grayB2, cmap="gray")
plt.colorbar()

# %%
fileA = "/Users/marco/Desktop/tesi/CampioniL/Aiyn - disegno/0029_D36.jpg"
img_grayA = cv2.imread(fileA, cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# # Main

# %%
# dataset path

path = '/Users/marco/Desktop/tesi/CampioniL'
#path = '/Users/marco/Desktop/tesi/Dataset_Egyptian_hieroglyphs/Manual/Preprocessed'

filelist = create_filelist(path, formato="jpg")          


#CREO DATASET 
subpath_list = []
new_dataset_path = '/Users/marco/Desktop/CampioniL_V3'
#new_dataset_path = '/Users/marco/Desktop/Oland_campioni'

if os.path.isdir(new_dataset_path):
    shutil.rmtree(new_dataset_path)

os.mkdir(new_dataset_path)
count = 0
for file in filelist:
    filename, subpath = file.split('/')[-1], file.split('/')[-2]
    if subpath not in subpath_list:
        os.mkdir(new_dataset_path + "/" + subpath)
        subpath_list.append(subpath)
    

    img_gray = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
    #img_gray = adjust_white_contorned_img(img_gray)
    #img_gray = resize_img(img_gray, 50, 75, NEAR_PIXEL=5)
    
    img_gray = refact_img(img_gray, 200, 200, NEAR_PIXEL=1)
    
    cv2.imwrite(new_dataset_path + "/" + subpath + "/" + filename, img_gray)
    count = count+1
    print(str(count) +"/"+ str(len(filelist)) + " image saved")
# Out:
# 1/1310 image saved
# 2/1310 image saved
# 3/1310 image saved
# 4/1310 image saved
# 5/1310 image saved
# 6/1310 image saved
# 7/1310 image saved
# 8/1310 image saved
# 9/1310 image saved
# 10/1310 image saved
# 11/1310 image saved
# 12/1310 image saved
# 13/1310 image saved
# 14/1310 image saved
# 15/1310 image saved
# 16/1310 image saved
# 17/1310 image saved
# 18/1310 image saved
# 19/1310 image saved
# 20/1310 image saved
# 21/1310 image saved
# 22/1310 image saved
# 23/1310 image saved
# 24/1310 image saved
# 25/1310 image saved
# 26/1310 image saved
# 27/1310 image saved
# 28/1310 image saved
# 29/1310 image saved
# 30/1310 image saved
# 31/1310 image saved
# 32/1310 image saved
# 33/1310 image saved
# 34/1310 image saved
# 35/1310 image saved
# 36/1310 image saved
# 37/1310 image saved
# 38/1310 image saved
# 39/1310 image saved
# 40/1310 image saved
# 41/1310 image saved
# 42/1310 image saved
# 43/1310 image saved
# 44/1310 image saved
# 45/1310 image saved
# 46/1310 image saved
# 47/1310 image saved
# 48/1310 image saved
# 49/1310 image saved
# 50/1310 image saved
# 51/1310 image saved
# 52/1310 image saved
# 53/1310 image saved
# 54/1310 image saved
# 55/1310 image saved
# 56/1310 image saved
# 57/1310 image saved
# 58/1310 image saved
# 59/1310 image saved
# 60/1310 image saved
# 61/1310 image saved
# 62/1310 image saved
# 63/1310 image saved
# 64/1310 image saved
# 65/1310 image saved
# 66/1310 image saved
# 67/1310 image saved
# 68/1310 image saved
# 69/1310 image saved
# 70/1310 image saved
# 71/1310 image saved
# 72/1310 image saved
# 73/1310 image saved
# 74/1310 image saved
# 75/1310 image saved
# 76/1310 image saved
# 77/1310 image saved
# 78/1310 image saved
# 79/1310 image saved
# 80/1310 image saved
# 81/1310 image saved
# 82/1310 image saved
# 83/1310 image saved
# 84/1310 image saved
# 85/1310 image saved
# 86/1310 image saved
# 87/1310 image saved
# 88/1310 image saved
# 89/1310 image saved
# 90/1310 image saved
# 91/1310 image saved
# 92/1310 image saved
# 93/1310 image saved
# 94/1310 image saved
# 95/1310 image saved
# 96/1310 image saved
# 97/1310 image saved
# 98/1310 image saved
# 99/1310 image saved
# 100/1310 image saved
# 101/1310 image saved
# 102/1310 image saved
# 103/1310 image saved
# 104/1310 image saved
# 105/1310 image saved
# 106/1310 image saved
# 107/1310 image saved
# 108/1310 image saved
# 109/1310 image saved
# 110/1310 image saved
# 111/1310 image saved
# 112/1310 image saved
# 113/1310 image saved
# 114/1310 image saved
# 115/1310 image saved
# 116/1310 image saved
# 117/1310 image saved
# 118/1310 image saved
# 119/1310 image saved
# 120/1310 image saved
# 121/1310 image saved
# 122/1310 image saved
# 123/1310 image saved
# 124/1310 image saved
# 125/1310 image saved
# 126/1310 image saved
# 127/1310 image saved
# 128/1310 image saved
# 129/1310 image saved
# 130/1310 image saved
# 131/1310 image saved
# 132/1310 image saved
# 133/1310 image saved
# 134/1310 image saved
# 135/1310 image saved
# 136/1310 image saved
# 137/1310 image saved
# 138/1310 image saved
# 139/1310 image saved
# 140/1310 image saved
# 141/1310 image saved
# 142/1310 image saved
# 143/1310 image saved
# 144/1310 image saved
# 145/1310 image saved
# 146/1310 image saved
# 147/1310 image saved
# 148/1310 image saved
# 149/1310 image saved
# 150/1310 image saved
# 151/1310 image saved
# 152/1310 image saved
# 153/1310 image saved
# 154/1310 image saved
# 155/1310 image saved
# 156/1310 image saved
# 157/1310 image saved
# 158/1310 image saved
# 159/1310 image saved
# 160/1310 image saved
# 161/1310 image saved
# 162/1310 image saved
# 163/1310 image saved
# 164/1310 image saved
# 165/1310 image saved
# 166/1310 image saved
# 167/1310 image saved
# 168/1310 image saved
# 169/1310 image saved
# 170/1310 image saved
# 171/1310 image saved
# 172/1310 image saved
# 173/1310 image saved
# 174/1310 image saved
# 175/1310 image saved
# 176/1310 image saved
# 177/1310 image saved
# 178/1310 image saved
# 179/1310 image saved
# 180/1310 image saved
# 181/1310 image saved
# 182/1310 image saved
# 183/1310 image saved
# 184/1310 image saved
# 185/1310 image saved
# 186/1310 image saved
# 187/1310 image saved
# 188/1310 image saved
# 189/1310 image saved
# 190/1310 image saved
# 191/1310 image saved
# 192/1310 image saved
# 193/1310 image saved
# 194/1310 image saved
# 195/1310 image saved
# 196/1310 image saved
# 197/1310 image saved
# 198/1310 image saved
# 199/1310 image saved
# 200/1310 image saved
# 201/1310 image saved
# 202/1310 image saved
# 203/1310 image saved
# 204/1310 image saved
# 205/1310 image saved
# 206/1310 image saved
# 207/1310 image saved
# 208/1310 image saved
# 209/1310 image saved
# 210/1310 image saved
# 211/1310 image saved
# 212/1310 image saved
# 213/1310 image saved
# 214/1310 image saved
# 215/1310 image saved
# 216/1310 image saved
# 217/1310 image saved
# 218/1310 image saved
# 219/1310 image saved
# 220/1310 image saved
# 221/1310 image saved
# 222/1310 image saved
# 223/1310 image saved
# 224/1310 image saved
# 225/1310 image saved
# 226/1310 image saved
# 227/1310 image saved
# 228/1310 image saved
# 229/1310 image saved
# 230/1310 image saved
# 231/1310 image saved
# 232/1310 image saved
# 233/1310 image saved
# 234/1310 image saved
# 235/1310 image saved
# 236/1310 image saved
# 237/1310 image saved
# 238/1310 image saved
# 239/1310 image saved
# 240/1310 image saved
# 241/1310 image saved
# 242/1310 image saved
# 243/1310 image saved
# 244/1310 image saved
# 245/1310 image saved
# 246/1310 image saved
# 247/1310 image saved
# 248/1310 image saved
# 249/1310 image saved
# 250/1310 image saved
# 251/1310 image saved
# 252/1310 image saved
# 253/1310 image saved
# 254/1310 image saved
# 255/1310 image saved
# 256/1310 image saved
# 257/1310 image saved
# 258/1310 image saved
# 259/1310 image saved
# 260/1310 image saved
# 261/1310 image saved
# 262/1310 image saved
# 263/1310 image saved
# 264/1310 image saved
# 265/1310 image saved
# 266/1310 image saved
# 267/1310 image saved
# 268/1310 image saved
# 269/1310 image saved
# 270/1310 image saved
# 271/1310 image saved
# 272/1310 image saved
# 273/1310 image saved
# 274/1310 image saved
# 275/1310 image saved
# 276/1310 image saved
# 277/1310 image saved
# 278/1310 image saved
# 279/1310 image saved
# 280/1310 image saved
# 281/1310 image saved
# 282/1310 image saved
# 283/1310 image saved
# 284/1310 image saved
# 285/1310 image saved
# 286/1310 image saved
# 287/1310 image saved
# 288/1310 image saved
# 289/1310 image saved
# 290/1310 image saved
# 291/1310 image saved
# 292/1310 image saved
# 293/1310 image saved
# 294/1310 image saved
# 295/1310 image saved
# 296/1310 image saved
# 297/1310 image saved
# 298/1310 image saved
# 299/1310 image saved
# 300/1310 image saved
# 301/1310 image saved
# 302/1310 image saved
# 303/1310 image saved
# 304/1310 image saved
# 305/1310 image saved
# 306/1310 image saved
# 307/1310 image saved
# 308/1310 image saved
# 309/1310 image saved
# 310/1310 image saved
# 311/1310 image saved
# 312/1310 image saved
# 313/1310 image saved
# 314/1310 image saved
# 315/1310 image saved
# 316/1310 image saved
# 317/1310 image saved
# 318/1310 image saved
# 319/1310 image saved
# 320/1310 image saved
# 321/1310 image saved
# 322/1310 image saved
# 323/1310 image saved
# 324/1310 image saved
# 325/1310 image saved
# 326/1310 image saved
# 327/1310 image saved
# 328/1310 image saved
# 329/1310 image saved
# 330/1310 image saved
# 331/1310 image saved
# 332/1310 image saved
# 333/1310 image saved
# 334/1310 image saved
# 335/1310 image saved
# 336/1310 image saved
# 337/1310 image saved
# 338/1310 image saved
# 339/1310 image saved
# 340/1310 image saved
# 341/1310 image saved
# 342/1310 image saved
# 343/1310 image saved
# 344/1310 image saved
# 345/1310 image saved
# 346/1310 image saved
# 347/1310 image saved
# 348/1310 image saved
# 349/1310 image saved
# 350/1310 image saved
# 351/1310 image saved
# 352/1310 image saved
# 353/1310 image saved
# 354/1310 image saved
# 355/1310 image saved
# 356/1310 image saved
# 357/1310 image saved
# 358/1310 image saved
# 359/1310 image saved
# 360/1310 image saved
# 361/1310 image saved
# 362/1310 image saved
# 363/1310 image saved
# 364/1310 image saved
# 365/1310 image saved
# 366/1310 image saved
# 367/1310 image saved
# 368/1310 image saved
# 369/1310 image saved
# 370/1310 image saved
# 371/1310 image saved
# 372/1310 image saved
# 373/1310 image saved
# 374/1310 image saved
# 375/1310 image saved
# 376/1310 image saved
# 377/1310 image saved
# 378/1310 image saved
# 379/1310 image saved
# 380/1310 image saved
# 381/1310 image saved
# 382/1310 image saved
# 383/1310 image saved
# 384/1310 image saved
# 385/1310 image saved
# 386/1310 image saved
# 387/1310 image saved
# 388/1310 image saved
# 389/1310 image saved
# 390/1310 image saved
# 391/1310 image saved
# 392/1310 image saved
# 393/1310 image saved
# 394/1310 image saved
# 395/1310 image saved
# 396/1310 image saved
# 397/1310 image saved
# 398/1310 image saved
# 399/1310 image saved
# 400/1310 image saved
# 401/1310 image saved
# 402/1310 image saved
# 403/1310 image saved
# 404/1310 image saved
# 405/1310 image saved
# 406/1310 image saved
# 407/1310 image saved
# 408/1310 image saved
# 409/1310 image saved
# 410/1310 image saved
# 411/1310 image saved
# 412/1310 image saved
# 413/1310 image saved
# 414/1310 image saved
# 415/1310 image saved
# 416/1310 image saved
# 417/1310 image saved
# 418/1310 image saved
# 419/1310 image saved
# 420/1310 image saved
# 421/1310 image saved
# 422/1310 image saved
# 423/1310 image saved
# 424/1310 image saved
# 425/1310 image saved
# 426/1310 image saved
# 427/1310 image saved
# 428/1310 image saved
# 429/1310 image saved
# 430/1310 image saved
# 431/1310 image saved
# 432/1310 image saved
# 433/1310 image saved
# 434/1310 image saved
# 435/1310 image saved
# 436/1310 image saved
# 437/1310 image saved
# 438/1310 image saved
# 439/1310 image saved
# 440/1310 image saved
# 441/1310 image saved
# 442/1310 image saved
# 443/1310 image saved
# 444/1310 image saved
# 445/1310 image saved
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-57818ffdf9d2> in <module>()
#      28     #img_gray = resize_img(img_gray, 50, 75, NEAR_PIXEL=5)
#      29
# ---> 30     img_gray = refact_img(img_gray, 200, 200, NEAR_PIXEL=1)
#      31
#      32     cv2.imwrite(new_dataset_path + "/" + subpath + "/" + filename, img_gray)
#
# <ipython-input-1-19b1a082dbe7> in refact_img(gray_img, out_w, out_h, NEAR_PIXEL)
#     210         for i,row in enumerate(thresh):
#     211             for j,pixel in enumerate(row):
# --> 212                 if pixel == 1:
#     213                     background[i, offset+j] = gray_img[i,j]
#     214
#
# KeyboardInterrupt:

# %%
# dataset path

name = "train_flip_aug"
path = '/Users/marco/Desktop/tesi/campioni/datasets(200x200)/'+ name

filelist = create_filelist(path, formato="jpg")          


#CREO DATASET 
subpath_list = []
new_dataset_path = '/Users/marco/Desktop/tesi/campioni/datasets(224x224)/'+name

if os.path.isdir(new_dataset_path):
    shutil.rmtree(new_dataset_path)

os.mkdir(new_dataset_path)
count = 0
for file in filelist:
    filename, subpath = file.split('/')[-1], file.split('/')[-2]
    if subpath not in subpath_list:
        os.mkdir(new_dataset_path + "/" + subpath)
        subpath_list.append(subpath)
    

    img_gray = cv2.imread(file, cv2.IMREAD_GRAYSCALE)
    
    img_gray = cv2.resize(img_gray, (224,224))
    
    cv2.imwrite(new_dataset_path + "/" + subpath + "/" + filename, img_gray)
    count = count+1
    print(str(count) +"/"+ str(len(filelist)) + " image saved")
